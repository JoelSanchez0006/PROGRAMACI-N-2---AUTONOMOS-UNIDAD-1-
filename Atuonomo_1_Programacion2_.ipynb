# %% [markdown]
# # ACTIVIDAD AUTONOMA 1 - PROGRAMACIÓN 2
#
# NOMBRE: Joel Adrian Sanchez Peña

# %% [markdown]
# # **1. Diseño de la clase**
#
# Cree una clase llamada AnalizadorDatos con los siguientes elementos:
#
# • Atributo: datos (una lista de números).
# • Métodos:
#
# o obtener_maximo() → devuelve el valor máximo.
#
# o obtener_minimo() → devuelve el valor mínimo.
#
# o calcular_media() → devuelve el promedio de los datos.
#
# o mostrar_resumen() → imprime todos los valores anteriores.

# %%
class AnalizadorDatos:
    def __init__(self, datos):
        self.datos = datos

    def obtener_maximo(self):
        return max(self.datos)

    def obtener_minimo(self):
        return min(self.datos)

    def calcular_media(self):
        media = sum(self.datos) / len(self.datos)
        return media

    def mostrar_resumen(self):
        print(" \n")
        print("==== Datos Analizados ====")
        print("Cantidad de datos: ", self.datos)
        print("Numero Maximo: ", self.obtener_maximo())
        print("Numero minimo: ", self.obtener_minimo())
        print("Media: ", self.calcular_media())
        print("Rango: ", self.obtener_maximo() - self.obtener_minimo())

    def agregar_dato(self, nuevo_valor):
        self.datos.append(nuevo_valor)

# %% [markdown]
# # **2. Implementación práctica**
# a) Cree manualmente una lista con al menos 10 valores numéricos
#
# (por ejemplo, calificaciones o temperaturas).
#
# b) Cree una instancia de la clase AnalizadorDatos usando esa lista.
#
# c) Ejecute los métodos definidos e interprete los resultados.
#
# d) Modifique el método mostrar_resumen() para que también
#
# muestre el rango de los datos (máximo – mínimo).

# %%
#lista de los datos
datos = [7.5, 4.6, 9, 4, 10, 8.5, 2, 21, 10, 18]

analizador = AnalizadorDatos(datos)

analizador.mostrar_resumen()
# Out:
#
#
# ==== Datos Analizados ====
# Cantidad de datos:  [7.5, 4.6, 9, 4, 10, 8.5, 2, 21, 10, 18]
# Numero Maximo:  21
# Numero minimo:  2
# Media:  9.459999999999999
# Rango:  19

# %% [markdown]
# # **3. Extensión: lectura dinámica**
# a) Añada a la clase un método agregar_dato(nuevo_valor) que
# permita añadir un nuevo número a la lista.
#
# b) Permita que el usuario ingrese varios valores por teclado hasta
# escribir “fin”.
#
# c) Luego, muestre nuevamente el resumen con los nuevos datos
# agregados.

# %%
while True:
    ingreso= input("Ingrese un número ('fin' para terminar): ")

    if ingreso.lower() == "fin":
        break

    analizador.agregar_dato(float(ingreso))

# Mostrar nuevo resumen
analizador.mostrar_resumen()
# Out:
# Ingrese un número ('fin' para terminar): 5
# Ingrese un número ('fin' para terminar): 3
# Ingrese un número ('fin' para terminar): 6
# Ingrese un número ('fin' para terminar): fin
#
#
# ==== Datos Analizados ====
# Cantidad de datos:  [7.5, 4.6, 9, 4, 10, 8.5, 2, 21, 10, 18, 5.0, 3.0, 6.0]
# Numero Maximo:  21
# Numero minimo:  2
# Media:  8.353846153846153
# Rango:  19
